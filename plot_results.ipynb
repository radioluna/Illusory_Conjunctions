# %%
import pandas as pd

#df = pandas.read_csv('hf_no_int.csv')
df = pandas.read_csv('int_data2.csv')
df_new = df.dropna(axis = 0, how ='any') 
df_new
# Out:
#     dBratio Choice  Confidence
# 0     -36.0      L       100.0
# 1     -12.0      L       100.0
# 2       0.0      L       100.0
# 3     -48.0      L       100.0
# 4     -48.0      L       100.0
# 5     -60.0      L       100.0
# 6     -12.0      L       100.0
# 7     -24.0      L       100.0
# 8      48.0      Y       100.0
# 9      48.0      Y       100.0
# 10     36.0      Y       100.0
# 11     60.0      Y       100.0
# 12     24.0      Y        95.0
# 13     24.0      L        93.0
# 14     12.0      L        85.0
# 15      0.0      L       100.0
# 16     60.0      Y       100.0
# 17     12.0      L        90.0
# 18    -60.0      L       100.0
# 19    -24.0      L       100.0
# 20    -36.0      L       100.0
# 21     36.0      Y       100.0
# 23      0.0      L        95.0
# 24     36.0      L        90.0
# 25    -12.0      L       100.0
# 26     60.0      L        73.0
# 27     60.0      L        75.0
# 28    -60.0      L       100.0
# 29     12.0      L       100.0
# ...

# %%
#df_new.plot(kind='scatter',x='dBratio',y='Confidence')
df_new.plot(kind='hist',x='dBratio',y='Confidence')

# %%
df_new.plot(kind='scatter',x='dBratio',y='Confidence')

# %%
for index, rows in df_new.iterrows():
    if (rows['Choice'])=='L':
        df_new.Choice[index]=1
    if (rows['Choice'])=='Y':
        df_new.Choice[index]=2
# Out:
# /Users/sharathchandra/anaconda/envs/py366/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/sharathchandra/anaconda/envs/py366/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sharathchandra/anaconda/envs/py366/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_new
# Out:
#     dBratio Choice  Confidence
# 0     -36.0      1       100.0
# 1     -12.0      1       100.0
# 2       0.0      1       100.0
# 3     -48.0      1       100.0
# 4     -48.0      1       100.0
# 5     -60.0      1       100.0
# 6     -12.0      1       100.0
# 7     -24.0      1       100.0
# 8      48.0      2       100.0
# 9      48.0      2       100.0
# 10     36.0      2       100.0
# 11     60.0      2       100.0
# 12     24.0      2        95.0
# 13     24.0      1        93.0
# 14     12.0      1        85.0
# 15      0.0      1       100.0
# 16     60.0      2       100.0
# 17     12.0      1        90.0
# 18    -60.0      1       100.0
# 19    -24.0      1       100.0
# 20    -36.0      1       100.0
# 21     36.0      2       100.0
# 23      0.0      1        95.0
# 24     36.0      1        90.0
# 25    -12.0      1       100.0
# 26     60.0      1        73.0
# 27     60.0      1        75.0
# 28    -60.0      1       100.0
# 29     12.0      1       100.0
# ...

# %%
df_new.plot.hist(x='dBratio', y='Choice',alpha=0.7)

# %%
col = df_new.Choice.map({1:'b', 2:'r'})

df_new.plot.scatter(x='dBratio', y='Confidence', c=col,alpha=0.4)
