# %%
import pandas as pd

df = pd.read_csv('f1_f2_data.csv')

df_new = df.dropna(axis = 0, how ='any') 
df_new
# Out:
#     dBratio        F1       F2
# 0       -60   643.417  1182.83
# 1       -48   643.510  1183.91
# 2       -36   644.340  1188.65
# 3       -24   650.370  1208.79
# 4       -12   684.030  1288.50
# 5         0   736.685  1961.15
# 6        12   769.380  2046.84
# 7        24   979.400  2055.26
# 8        36  1377.400  2061.39
# 9        48  1516.110  2065.98
# 10       60  1545.370  2067.62

# %%
df_new.plot(kind='line',x='dBratio',y=['F1','F2'])
df_new.plot(kind='line',x='dBratio',y=['F1'])
df_new.plot(kind='line',x='dBratio',y=['F2'])

# %%
df_new.plot(kind='scatter',x='F1',y='F2')
